# %% [markdown]
# # Cluster gridded data

# %% [markdown]
# ### This example script clusters era5 windfields at 850 hPa and saves the clusters to a netcdf file

# %% [markdown]
# ## Load packages

# %%
import sys
sys.path.append('/home/565/fl2086/Australian-synoptic-weather-types/utils/') # Path to utils scripts
import read_era5 as era5
import kmeans_clustering as kmeans

# %% [markdown]
# ## Input settings

# %%
date_start = '1952-01' # Start year-month for clustering data yyyy-mm
date_end   = '2023-12' # End year-month for clustering data yyyy-mm (included)
utc        = 12        # Clustering sampling time (utc) data is sampled daily
plevel     = 850       # Height level used (hPa)
lat_lims   = [-5,-50]  # South and North lattitude limit of analysis box
lon_lims   = [100,165] # West and East longitude limit of analysis box
Ncoarsen   = 6         # Coarsening factor in lat and lon direction
Nclusters  = 10        # Number of clusters for kmeans clustering
path_out   = "/home/565/fl2086/Australian-synoptic-weather-types/clustering/" # Directory to save cluster results
path_data  = "/g/data/rt52/era5/pressure-levels/reanalysis/"         # Era5 data directory
n_jobs     = 1          # Processes used for clustering

# %% [markdown]
# ## Load data

# %%
print('Read u fields')
u,time,lat,lon = era5.read_data('u',date_start,date_end,utc,lat_lims,lon_lims,path_data,Ncoarsen=Ncoarsen,level=plevel,progress=True)
print('Read v fields')
v,_,_,_        = era5.read_data('v',date_start,date_end,utc,lat_lims,lon_lims,path_data,Ncoarsen=Ncoarsen,level=plevel,progress=True)
# Out:
# Read u fields
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 2
#       1 print('Read u fields')
# ----> 2 u,time,lat,lon = era5.read_data('u',date_start,date_end,utc,lat_lims,lon_lims,path_data,Ncoarsen=Ncoarsen,plevel=plevel,progress=True)
#       3 print('Read v fields')
#       4 v,_,_,_        = era5.read_data('v',date_start,date_end,utc,lat_lims,lon_lims,path_data,Ncoarsen=Ncoarsen,plevel=plevel,progress=True)
#
# TypeError: read_data() got an unexpected keyword argument 'plevel'

# %% [markdown]
# ## Clustering

# %%
# Stack u, v data
uv_stack = kmeans.stack(u,v)
# Cluster
clusterU,clusterV,labels,inertia,silhouette = kmeans.cluster(uv_stack,lat,lon,Nclusters,n_jobs=1)
# Save output
kmeans.save(f"{path_out}clusters_{Nclusters}.nc",Nclusters,time,lat,lon,clusterU,clusterV,labels,inertia,silhouette)
